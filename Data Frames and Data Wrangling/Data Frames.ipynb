# %% [markdown]
# # Data Frames

# %% [markdown]
# ## Data Loading

# %%
# load scikit-learn's datasets
from sklearn import datasets
# load digits dataset
digits = datasets. load_digits ()
# create features matrix
features = digits.data
# create target vector target
target = digits.target
# view first observation
features [0]

# %% [markdown]
# ## Regression

# %%
# load library
from sklearn.datasets import make_regression
# generate features matrix, target vector, and the true coefficients
features, target, coefficients = make_regression (n_samples = 100,
                                                  n_features = 3,
                                                  n_informative = 3,
                                                  n_targets = 1,
                                                  noise = 0.0,
                                                  coef=True,
                                                  random_state = 1)
# view feature matrix and target vector
print("Feature Matrix \n {}".format(features [:3]))
print("Target Vector \n {}".format(target [:3]))

# %% [markdown]
# ## Classification

# %%
# load library
from sklearn.datasets import make_classification
# generate features matrix and target vector
features, target = make_classification (n_samples = 100,
                                        n_features = 3,
                                        n_informative = 3,
                                        n_redundant = 0,
                                        n_classes = 2,
                                        weights = [.25, .75],
                                        random_state = 1)
# view feature matrix and target vector
print("Feature matrix\n {}".format(features [:3]))
print("Target vector\n {}".format(target [:3]))

# %% [markdown]
# ## Clustering

# %%
# load library
from sklearn.datasets import make_blobs
# generate feature_matrix and target vector
features, target = make_blobs (n_samples = 100,
                               n_features = 2,
                               centers = 3,
                               cluster_std= 0.5,
                               shuffle = True,
                               random_state= 1)
# view feature matrix and target vector
print("Feature Matrix\n {}".format(features [:3]))
print("Target Vector\n {}".format(target [:3]))

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
# view scatterplot
plt.scatter(features [:, 0], features [:, 1], c=target)
plt.show()

# %% [markdown]
# ## CSV

# %%
import pandas as pd

url = r"/content/Cars Datasets 2025 (1).csv"

df = pd.read_csv(url)
df.head(2)

# %% [markdown]
# ## Excel

# %%
import pandas as pd
# create url
url = "/content/HR Details.xlsx"
# load data
df = pd.read_excel (url, sheet_name=0, header=None)

# %% [markdown]
# ## JSON

# %%
# load library
import pandas as pd
# create url
url = "/content/datanew.json"
# load data
df = pd.read_json(url, orient="columns")
# view first two rows
df.head (2)

# %% [markdown]
# ## Database

# %%
import pandas as pd
import sqlite3

con=sqlite3.connect("/content/sqlite-sakila.db")
df = pd.read_sql_query("SELECT * FROM actor", con)
df.head()
